# %%
import os
from PIL import Image
import pytesseract #used for ocr
from mss import mss #used for recording screen app
import pydirectinput # used for sending command to game regarding actions
import cv2 #allow to do image processing
from matplotlib import pyplot as plt
import time
import gymnasium as gym
from gymnasium.spaces import Box, Discrete
import numpy as np
from IPython.display import display, Image

# For DQN
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common import env_checker
from stable_baselines3 import DQN

pydirectinput.FAILSAFE = False

# %% [markdown]
# ### Build Environment

# %%
class WebGame(gym.Env):
    def __init__(self):
        # Subclass model
        super().__init__()
        # Setup Spaces
        self.observation_space = Box(low=0, high=255, shape=(1,83,100), dtype=np.uint8)
        self.action_space = Discrete(3)
        # Define extraction parameters for the game
        self.cap = mss()
        self.game_location = {'top': 400, 'left': 0, 'width': 600, 'height': 500}
        self.done_location = {'top': 480, 'left': 550, 'width': 800, 'height': 100}

    def step(self, action):
        action_map = {
            0: 'space',
            1: 'down',
            2: 'no_op'
        }
        if action != 2:
            pydirectinput.press(action_map[action])
        
        terminated = self.get_done()
        truncated = False  # You can set this to True if you implement truncation logic
        new_observations = self.get_observation()
        reward = 1
        info = {}
        
        return new_observations, reward, terminated, truncated, info
    
    def render(self):
        frame = np.array(self.cap.grab(self.game_location))[:, :, :3]
        cv2.imwrite('frame.jpg', frame)
        display(Image(filename='frame.jpg'))
    
    def reset(self, seed=None, options=None):
        # Optionally set the seed
        if seed is not None:
            np.random.seed(seed)
        
        time.sleep(1)
        pydirectinput.click(x=150, y=150)
        pydirectinput.press('space')
        observation = self.get_observation()
        info = {}  # You can return additional info if needed
        return observation, info
    
    def close(self):
        cv2.destroyAllWindows()
    
    def get_observation(self):
        raw = np.array(self.cap.grab(self.game_location))[:, :, :3]
        gray = cv2.cvtColor(raw, cv2.COLOR_BGR2GRAY)
        resized = cv2.resize(gray, (100, 83))
        channel = np.reshape(resized, (1, 83, 100))
        return channel
    
    def get_done(self):
        done_cap = np.array(self.cap.grab(self.done_location))[:, :, :3]
        res = pytesseract.image_to_string(done_cap)
        done_strings = ['OVE', 'GAME', 'chrome', 'OVER', 'enterprise', 'GAME', 'OVER\n']
        res = res.split(" ")
        if any(word in res for word in done_strings):
            return True
        return False

# %%
env = WebGame()

# %%
# Testing our environment Logics

for episodes in range(10):
    obs = env.reset()
    done = False
    total_reward = 0
    
    while not done:
        obs, reward, done, trunc, info = env.step(env.action_space.sample())
        total_reward += reward
    print(f'Total Reward for ep isodes {episodes} is {total_reward}')
# Out:
# Total Reward for ep isodes 0 is 11
# Total Reward for ep isodes 1 is 15
# Total Reward for ep isodes 2 is 12
# Total Reward for ep isodes 3 is 10
# Total Reward for ep isodes 4 is 10
# Total Reward for ep isodes 5 is 17
# Total Reward for ep isodes 6 is 31
# Total Reward for ep isodes 7 is 11
# Total Reward for ep isodes 8 is 13
# Total Reward for ep isodes 9 is 10

# %% [markdown]
# ### Using Deep Reinforcement Algorithm (DQN)

# %%
# This help us to check if our created environment is workig perfectly or not
# env_checker.check_env(env)

# %%
class TrainAndLoggingCallback(BaseCallback):
    
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path
        
    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
            
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)
        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs'

# %%
callback = TrainAndLoggingCallback(check_freq=1000, save_path=CHECKPOINT_DIR)

# %%
model = DQN(
        'CnnPolicy', 
        env, 
        tensorboard_log=LOG_DIR, 
        verbose=1, 
        buffer_size=1000000, 
        learning_starts=1000
    )
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\Moiz Ahmed\my-work\RL_Projects\venv\Lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 16.62GB > 2.96GB
#   warnings.warn(

# %%
model.learn(total_timesteps=2000, callback=callback)
# Out:
# Logging to ./logs\DQN_5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 model.learn(total_timesteps=2000, callback=callback)
#
# File c:\Users\Moiz Ahmed\my-work\RL_Projects\venv\Lib\site-packages\stable_baselines3\dqn\dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File c:\Users\Moiz Ahmed\my-work\RL_Projects\venv\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File c:\Users\Moiz Ahmed\my-work\RL_Projects\venv\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:560, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     557 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     559 # Rescale and perform action
# --> 560 new_obs, rewards, dones, infos = env.step(actions)
#     562 self.num_timesteps += env.num_envs
#     563 num_collected_steps += 1
#
# File c:\Users\Moiz Ahmed\my-work\RL_Projects\venv\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File c:\Users\Moiz Ahmed\my-work\RL_Projects\venv\Lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File c:\Users\Moiz Ahmed\my-work\RL_Projects\venv\Lib\site-packages\stable_baselines3\common\monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# Cell In[2], line 20, in WebGame.step(self, action)
#      14 action_map = {
#      15     0: 'space',
#      16     1: 'down',
#      17     2: 'no_op'
#      18 }
#      19 if action != 2:
# ---> 20     pydirectinput.press(action_map[action])
#      22 terminated = self.get_done()
#      23 truncated = False  # You can set this to True if you implement truncation logic
#
# File c:\Users\Moiz Ahmed\my-work\RL_Projects\venv\Lib\site-packages\pydirectinput\__init__.py:242, in _genericPyDirectInputChecks.<locals>.wrapper(*args, **kwargs)
#     239 funcArgs = inspect.getcallargs(wrappedFunction, *args, **kwargs)
#     241 failSafeCheck()
# --> 242 returnVal = wrappedFunction(*args, **kwargs)
#     243 _handlePause(funcArgs.get("_pause"))
#     244 return returnVal
#
# File c:\Users\Moiz Ahmed\my-work\RL_Projects\venv\Lib\site-packages\pydirectinput\__init__.py:545, in press(keys, presses, interval, logScreenshot, _pause)
#     543 failSafeCheck()
#     544 downed = keyDown(k)
# --> 545 upped = keyUp(k)
#     546 # Count key press as complete if key was "downed" and "upped" successfully
#     547 if downed and upped:
#
# File c:\Users\Moiz Ahmed\my-work\RL_Projects\venv\Lib\site-packages\pydirectinput\__init__.py:243, in _genericPyDirectInputChecks.<locals>.wrapper(*args, **kwargs)
#     241 failSafeCheck()
#     242 returnVal = wrappedFunction(*args, **kwargs)
# --> 243 _handlePause(funcArgs.get("_pause"))
#     244 return returnVal
#
# File c:\Users\Moiz Ahmed\my-work\RL_Projects\venv\Lib\site-packages\pydirectinput\__init__.py:232, in _handlePause(_pause)
#     230 if _pause:
#     231     assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 232     time.sleep(PAUSE)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Test Best Model

# %%
model = DQN('CnnPolicy', env, buffer_size=10000)
model.set_parameters(os.path.join('train', 'best_model_50000'))

for episodes in range(15):
    obs, info = env.reset()
    done = False
    total_reward = 0
    
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, trunc, info = env.step(int(action))
        total_reward += reward
    print(f'Total Reward for episodes {episodes} is {total_reward}')
# Out:
# Total Reward for episodes 0 is 26
# Total Reward for episodes 1 is 33
# Total Reward for episodes 2 is 20
# Total Reward for episodes 3 is 19
# Total Reward for episodes 4 is 21
# Total Reward for episodes 5 is 40
# Total Reward for episodes 6 is 34
# Total Reward for episodes 7 is 23
# Total Reward for episodes 8 is 31
# Total Reward for episodes 9 is 23
# Total Reward for episodes 10 is 22
# Total Reward for episodes 11 is 47
# Total Reward for episodes 12 is 189
# Total Reward for episodes 13 is 25
# Total Reward for episodes 14 is 33

# %% [markdown]
# ### Training DQN for further timestamps

# %%
model = DQN.load(os.path.join(CHECKPOINT_DIR, 'best_model_3000.zip'), env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\Moiz Ahmed\my-work\RL_Projects\venv\Lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 16.62GB > 4.96GB
#   warnings.warn(

# %%
additional_timesteps = 60000  # Adjust as needed
model.learn(total_timesteps=additional_timesteps, callback=callback)
# Out:
# Logging to ./logs\DQN_4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.2     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1        |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 73       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1        |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 121      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1        |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 166      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1        |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 217      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1        |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 272      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1        |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 352      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1        |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 400      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1        |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 451      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1        |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 504      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1        |
# |    time_elapsed     | 279      |
# |    total_timesteps  | 553      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1        |
# |    time_elapsed     | 311      |
# |    total_timesteps  | 617      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1        |
# |    time_elapsed     | 337      |
# |    total_timesteps  | 668      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1        |
# |    time_elapsed     | 371      |
# |    total_timesteps  | 737      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1        |
# |    time_elapsed     | 402      |
# |    total_timesteps  | 802      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1        |
# |    time_elapsed     | 435      |
# |    total_timesteps  | 867      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1        |
# |    time_elapsed     | 466      |
# |    total_timesteps  | 928      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1        |
# |    time_elapsed     | 494      |
# |    total_timesteps  | 981      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1        |
# |    time_elapsed     | 521      |
# |    total_timesteps  | 1027     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.43e-05 |
# |    n_updates        | 255      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1        |
# |    time_elapsed     | 548      |
# |    total_timesteps  | 1076     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.78e-05 |
# |    n_updates        | 267      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1        |
# |    time_elapsed     | 580      |
# |    total_timesteps  | 1140     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.74e-06 |
# |    n_updates        | 283      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1        |
# |    time_elapsed     | 613      |
# |    total_timesteps  | 1203     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.66e-05 |
# |    n_updates        | 299      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1        |
# |    time_elapsed     | 643      |
# |    total_timesteps  | 1260     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.94e-06 |
# |    n_updates        | 313      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.793    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1        |
# |    time_elapsed     | 668      |
# |    total_timesteps  | 1309     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.16e-05 |
# |    n_updates        | 326      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1        |
# |    time_elapsed     | 695      |
# |    total_timesteps  | 1362     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.43e-06 |
# |    n_updates        | 339      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1        |
# |    time_elapsed     | 733      |
# |    total_timesteps  | 1445     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.67e-06 |
# |    n_updates        | 360      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1        |
# |    time_elapsed     | 764      |
# |    total_timesteps  | 1507     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.07e-06 |
# |    n_updates        | 375      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1        |
# |    time_elapsed     | 800      |
# |    total_timesteps  | 1586     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.6e-06  |
# |    n_updates        | 395      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.738    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1        |
# |    time_elapsed     | 834      |
# |    total_timesteps  | 1653     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.69e-06 |
# |    n_updates        | 412      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.729    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1        |
# |    time_elapsed     | 864      |
# |    total_timesteps  | 1710     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.8e-06  |
# |    n_updates        | 426      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1        |
# |    time_elapsed     | 890      |
# |    total_timesteps  | 1763     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.34e-06 |
# |    n_updates        | 439      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1        |
# |    time_elapsed     | 917      |
# |    total_timesteps  | 1809     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.46e-05 |
# |    n_updates        | 451      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.697    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1        |
# |    time_elapsed     | 962      |
# |    total_timesteps  | 1911     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.39e-06 |
# |    n_updates        | 476      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.688    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1        |
# |    time_elapsed     | 994      |
# |    total_timesteps  | 1968     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.35e-06 |
# |    n_updates        | 490      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.677    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1        |
# |    time_elapsed     | 1028     |
# |    total_timesteps  | 2040     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.15e-06 |
# |    n_updates        | 508      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.669    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1        |
# |    time_elapsed     | 1054     |
# |    total_timesteps  | 2090     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.43e-05 |
# |    n_updates        | 521      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.656    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1        |
# |    time_elapsed     | 1089     |
# |    total_timesteps  | 2170     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.11e-05 |
# |    n_updates        | 541      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.648    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1        |
# |    time_elapsed     | 1114     |
# |    total_timesteps  | 2220     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14e-05 |
# |    n_updates        | 553      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.637    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1        |
# |    time_elapsed     | 1148     |
# |    total_timesteps  | 2293     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.66e-06 |
# |    n_updates        | 572      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1        |
# |    time_elapsed     | 1172     |
# |    total_timesteps  | 2340     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.6e-06  |
# |    n_updates        | 583      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2        |
# |    time_elapsed     | 1199     |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.8e-06  |
# |    n_updates        | 598      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.611    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 2        |
# |    time_elapsed     | 1226     |
# |    total_timesteps  | 2458     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.75e-06 |
# |    n_updates        | 613      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.598    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 2        |
# |    time_elapsed     | 1260     |
# |    total_timesteps  | 2537     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.08e-06 |
# |    n_updates        | 633      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 2        |
# |    time_elapsed     | 1285     |
# |    total_timesteps  | 2583     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.34e-05 |
# |    n_updates        | 644      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.582    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 2        |
# |    time_elapsed     | 1315     |
# |    total_timesteps  | 2641     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.78e-06 |
# |    n_updates        | 659      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.57     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 2        |
# |    time_elapsed     | 1346     |
# |    total_timesteps  | 2713     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15e-05 |
# |    n_updates        | 677      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 15.9     |
# |    exploration_rate | 0.557    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 2        |
# |    time_elapsed     | 1383     |
# |    total_timesteps  | 2797     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.11e-05 |
# |    n_updates        | 698      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.546    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 2        |
# |    time_elapsed     | 1414     |
# |    total_timesteps  | 2865     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.6e-05  |
# |    n_updates        | 715      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.532    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 2        |
# |    time_elapsed     | 1454     |
# |    total_timesteps  | 2958     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00725  |
# |    n_updates        | 738      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.524    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 2        |
# |    time_elapsed     | 1479     |
# |    total_timesteps  | 3006     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.49e-06 |
# |    n_updates        | 750      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 2        |
# |    time_elapsed     | 1516     |
# |    total_timesteps  | 3095     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00453  |
# |    n_updates        | 772      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.496    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 2        |
# |    time_elapsed     | 1554     |
# |    total_timesteps  | 3183     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.16e-05 |
# |    n_updates        | 794      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 16.7     |
# |    exploration_rate | 0.485    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 2        |
# |    time_elapsed     | 1589     |
# |    total_timesteps  | 3254     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.57e-05 |
# |    n_updates        | 812      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 16.6     |
# |    exploration_rate | 0.476    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 2        |
# |    time_elapsed     | 1614     |
# |    total_timesteps  | 3308     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.72e-05 |
# |    n_updates        | 825      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 16.7     |
# |    exploration_rate | 0.465    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 2        |
# |    time_elapsed     | 1645     |
# |    total_timesteps  | 3378     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.65e-05 |
# |    n_updates        | 843      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 16.6     |
# |    exploration_rate | 0.458    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 2        |
# |    time_elapsed     | 1670     |
# |    total_timesteps  | 3426     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.6e-05  |
# |    n_updates        | 855      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.448    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 2        |
# |    time_elapsed     | 1699     |
# |    total_timesteps  | 3489     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.42e-05 |
# |    n_updates        | 871      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.3     |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 2        |
# |    time_elapsed     | 1724     |
# |    total_timesteps  | 3544     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.6e-05  |
# |    n_updates        | 884      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.3     |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.431    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 2        |
# |    time_elapsed     | 1752     |
# |    total_timesteps  | 3596     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.93e-05 |
# |    n_updates        | 897      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.423    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 2        |
# |    time_elapsed     | 1777     |
# |    total_timesteps  | 3643     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.61e-05 |
# |    n_updates        | 909      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 2        |
# |    time_elapsed     | 1801     |
# |    total_timesteps  | 3697     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.17e-05 |
# |    n_updates        | 923      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.407    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 2        |
# |    time_elapsed     | 1826     |
# |    total_timesteps  | 3745     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.36e-05 |
# |    n_updates        | 935      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 15.9     |
# |    exploration_rate | 0.397    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 2        |
# |    time_elapsed     | 1858     |
# |    total_timesteps  | 3808     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.41e-06 |
# |    n_updates        | 950      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.39     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 2        |
# |    time_elapsed     | 1883     |
# |    total_timesteps  | 3855     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.29e-05 |
# |    n_updates        | 962      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.382    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 2        |
# |    time_elapsed     | 1908     |
# |    total_timesteps  | 3905     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02e-05 |
# |    n_updates        | 975      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.373    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 2        |
# |    time_elapsed     | 1935     |
# |    total_timesteps  | 3959     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.5e-05  |
# |    n_updates        | 988      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.364    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 2        |
# |    time_elapsed     | 1961     |
# |    total_timesteps  | 4017     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.88e-06 |
# |    n_updates        | 1003     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.356    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 2        |
# |    time_elapsed     | 1986     |
# |    total_timesteps  | 4065     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.62e-05 |
# |    n_updates        | 1015     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.346    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 2        |
# |    time_elapsed     | 2020     |
# |    total_timesteps  | 4131     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000115 |
# |    n_updates        | 1031     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.337    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 2        |
# |    time_elapsed     | 2050     |
# |    total_timesteps  | 4188     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38e-05 |
# |    n_updates        | 1045     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 2        |
# |    time_elapsed     | 2079     |
# |    total_timesteps  | 4237     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.65e-06 |
# |    n_updates        | 1058     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.318    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 2        |
# |    time_elapsed     | 2111     |
# |    total_timesteps  | 4309     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.28e-05 |
# |    n_updates        | 1076     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.305    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 2        |
# |    time_elapsed     | 2147     |
# |    total_timesteps  | 4392     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000492 |
# |    n_updates        | 1096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.297    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 2        |
# |    time_elapsed     | 2175     |
# |    total_timesteps  | 4441     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.93e-05 |
# |    n_updates        | 1109     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.29     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 2        |
# |    time_elapsed     | 2200     |
# |    total_timesteps  | 4485     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00041  |
# |    n_updates        | 1120     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.282    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 2        |
# |    time_elapsed     | 2225     |
# |    total_timesteps  | 4532     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.53e-05 |
# |    n_updates        | 1131     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.275    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 2        |
# |    time_elapsed     | 2250     |
# |    total_timesteps  | 4582     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.01e-05 |
# |    n_updates        | 1144     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.255    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 2        |
# |    time_elapsed     | 2302     |
# |    total_timesteps  | 4705     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00101  |
# |    n_updates        | 1175     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.249    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 2        |
# |    time_elapsed     | 2326     |
# |    total_timesteps  | 4744     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.81e-05 |
# |    n_updates        | 1184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.241    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 2        |
# |    time_elapsed     | 2353     |
# |    total_timesteps  | 4794     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.84e-05 |
# |    n_updates        | 1197     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.231    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 2        |
# |    time_elapsed     | 2377     |
# |    total_timesteps  | 4854     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37e-05 |
# |    n_updates        | 1212     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.224    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 2        |
# |    time_elapsed     | 2403     |
# |    total_timesteps  | 4901     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.84e-05 |
# |    n_updates        | 1224     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.215    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 2        |
# |    time_elapsed     | 2428     |
# |    total_timesteps  | 4955     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.65e-05 |
# |    n_updates        | 1237     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.205    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 2        |
# |    time_elapsed     | 2453     |
# |    total_timesteps  | 5019     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02e-05 |
# |    n_updates        | 1253     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.197    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 2        |
# |    time_elapsed     | 2478     |
# |    total_timesteps  | 5069     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.97e-06 |
# |    n_updates        | 1266     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.174    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 2        |
# |    time_elapsed     | 2529     |
# |    total_timesteps  | 5215     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.51e-05 |
# |    n_updates        | 1302     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.164    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 2        |
# |    time_elapsed     | 2561     |
# |    total_timesteps  | 5279     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.17e-05 |
# |    n_updates        | 1318     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.148    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 2        |
# |    time_elapsed     | 2600     |
# |    total_timesteps  | 5378     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14e-05 |
# |    n_updates        | 1343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.142    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 2        |
# |    time_elapsed     | 2625     |
# |    total_timesteps  | 5420     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.37e-06 |
# |    n_updates        | 1353     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.127    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 2        |
# |    time_elapsed     | 2657     |
# |    total_timesteps  | 5513     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.28e-05 |
# |    n_updates        | 1377     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.117    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 2        |
# |    time_elapsed     | 2682     |
# |    total_timesteps  | 5579     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.19e-06 |
# |    n_updates        | 1393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.108    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 2        |
# |    time_elapsed     | 2706     |
# |    total_timesteps  | 5631     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.81e-05 |
# |    n_updates        | 1406     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.0947   |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 2        |
# |    time_elapsed     | 2742     |
# |    total_timesteps  | 5718     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.22e-05 |
# |    n_updates        | 1428     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.0859   |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 2        |
# |    time_elapsed     | 2767     |
# |    total_timesteps  | 5773     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.04e-06 |
# |    n_updates        | 1442     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.3     |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.0782   |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 2        |
# |    time_elapsed     | 2791     |
# |    total_timesteps  | 5822     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.07e-06 |
# |    n_updates        | 1454     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.0696   |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 2        |
# |    time_elapsed     | 2816     |
# |    total_timesteps  | 5876     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.58e-05 |
# |    n_updates        | 1467     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.0606   |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 2        |
# |    time_elapsed     | 2840     |
# |    total_timesteps  | 5933     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.28e-06 |
# ...
# |    time_elapsed     | 23312    |
# |    total_timesteps  | 56955    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.59     |
# |    n_updates        | 14237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2976     |
# |    fps              | 2        |
# |    time_elapsed     | 23337    |
# |    total_timesteps  | 56998    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.116    |
# |    n_updates        | 14248    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2980     |
# |    fps              | 2        |
# |    time_elapsed     | 23372    |
# |    total_timesteps  | 57072    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.331    |
# |    n_updates        | 14266    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2984     |
# |    fps              | 2        |
# |    time_elapsed     | 23400    |
# |    total_timesteps  | 57128    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.201    |
# |    n_updates        | 14280    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2988     |
# |    fps              | 2        |
# |    time_elapsed     | 23426    |
# |    total_timesteps  | 57185    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.14     |
# |    n_updates        | 14295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2992     |
# |    fps              | 2        |
# |    time_elapsed     | 23452    |
# |    total_timesteps  | 57237    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.291    |
# |    n_updates        | 14308    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2996     |
# |    fps              | 2        |
# |    time_elapsed     | 23480    |
# |    total_timesteps  | 57311    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.23     |
# |    n_updates        | 14326    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3000     |
# |    fps              | 2        |
# |    time_elapsed     | 23514    |
# |    total_timesteps  | 57381    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.467    |
# |    n_updates        | 14344    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3004     |
# |    fps              | 2        |
# |    time_elapsed     | 23542    |
# |    total_timesteps  | 57451    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.282    |
# |    n_updates        | 14361    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3008     |
# |    fps              | 2        |
# |    time_elapsed     | 23579    |
# |    total_timesteps  | 57536    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.392    |
# |    n_updates        | 14382    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3012     |
# |    fps              | 2        |
# |    time_elapsed     | 23604    |
# |    total_timesteps  | 57596    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.207    |
# |    n_updates        | 14397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3016     |
# |    fps              | 2        |
# |    time_elapsed     | 23634    |
# |    total_timesteps  | 57661    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.316    |
# |    n_updates        | 14414    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3020     |
# |    fps              | 2        |
# |    time_elapsed     | 23659    |
# |    total_timesteps  | 57725    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.023    |
# |    n_updates        | 14430    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3024     |
# |    fps              | 2        |
# |    time_elapsed     | 23685    |
# |    total_timesteps  | 57793    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 14447    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3028     |
# |    fps              | 2        |
# |    time_elapsed     | 23711    |
# |    total_timesteps  | 57859    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0642   |
# |    n_updates        | 14463    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3032     |
# |    fps              | 2        |
# |    time_elapsed     | 23737    |
# |    total_timesteps  | 57942    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0369   |
# |    n_updates        | 14484    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3036     |
# |    fps              | 2        |
# |    time_elapsed     | 23769    |
# |    total_timesteps  | 58054    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.16     |
# |    n_updates        | 14512    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3040     |
# |    fps              | 2        |
# |    time_elapsed     | 23801    |
# |    total_timesteps  | 58170    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.413    |
# |    n_updates        | 14541    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3044     |
# |    fps              | 2        |
# |    time_elapsed     | 23836    |
# |    total_timesteps  | 58298    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0949   |
# |    n_updates        | 14573    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3048     |
# |    fps              | 2        |
# |    time_elapsed     | 23864    |
# |    total_timesteps  | 58393    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0981   |
# |    n_updates        | 14597    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3052     |
# |    fps              | 2        |
# |    time_elapsed     | 23891    |
# |    total_timesteps  | 58494    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.371    |
# |    n_updates        | 14622    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3056     |
# |    fps              | 2        |
# |    time_elapsed     | 23917    |
# |    total_timesteps  | 58585    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.161    |
# |    n_updates        | 14645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.6     |
# |    ep_rew_mean      | 18.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3060     |
# |    fps              | 2        |
# |    time_elapsed     | 23942    |
# |    total_timesteps  | 58673    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.335    |
# |    n_updates        | 14667    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3064     |
# |    fps              | 2        |
# |    time_elapsed     | 24015    |
# |    total_timesteps  | 58997    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0271   |
# |    n_updates        | 14748    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3068     |
# |    fps              | 2        |
# |    time_elapsed     | 24041    |
# |    total_timesteps  | 59085    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.388    |
# |    n_updates        | 14770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3072     |
# |    fps              | 2        |
# |    time_elapsed     | 24074    |
# |    total_timesteps  | 59202    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.515    |
# |    n_updates        | 14799    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3076     |
# |    fps              | 2        |
# |    time_elapsed     | 24123    |
# |    total_timesteps  | 59384    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0884   |
# |    n_updates        | 14844    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3080     |
# |    fps              | 2        |
# |    time_elapsed     | 24154    |
# |    total_timesteps  | 59488    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0928   |
# |    n_updates        | 14870    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26       |
# |    ep_rew_mean      | 26       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3084     |
# |    fps              | 2        |
# |    time_elapsed     | 24208    |
# |    total_timesteps  | 59725    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0832   |
# |    n_updates        | 14930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.3     |
# |    ep_rew_mean      | 26.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3088     |
# |    fps              | 2        |
# |    time_elapsed     | 24233    |
# |    total_timesteps  | 59817    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.358    |
# |    n_updates        | 14953    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27       |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3092     |
# |    fps              | 2        |
# |    time_elapsed     | 24265    |
# |    total_timesteps  | 59938    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.236    |
# |    n_updates        | 14983    |
# ----------------------------------
